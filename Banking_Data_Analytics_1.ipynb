# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Banking.csv')

# %%
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
bins =[0,100000,300000,float('inf')]
labels = ['low','medium','high']
df['Income_band'] =  pd.cut(df['Estimated Income'],bins=bins,labels=labels, right=False)

# %%
df['Income_band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income_band'>

# %%
df.columns
# Out:
# Index(['Client ID', 'Name', 'Age', 'Location ID', 'Joined Bank',
#        'Banking Contact', 'Nationality', 'Occupation', 'Fee Structure',
#        'Loyalty Classification', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Credit Card Balance', 'Bank Loans',
#        'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
#        'Foreign Currency Account', 'Business Lending', 'Properties Owned',
#        'Risk Weighting', 'BRId', 'GenderId', 'IAId', 'Income_band'],
#       dtype='object')

# %%
categorical_columns = df[['BRId', 'GenderId', 'IAId', 'Amount of Credit Cards','Nationality', 'Occupation', 'Fee Structure','Loyalty Classification','Income_band','Properties Owned',
       'Risk Weighting']].columns
for columns in categorical_columns:
  print(f"value counts for '{columns}':")
  display(df[columns].value_counts())
# Out:
# value counts for 'BRId':
# BRId
# 3    1352
# 1     660
# 2     495
# 4     493
# Name: count, dtype: int64
# value counts for 'GenderId':
# GenderId
# 2    1512
# 1    1488
# Name: count, dtype: int64
# value counts for 'IAId':
# IAId
# 1     177
# 2     177
# 3     177
# 4     177
# 8     177
# 9     176
# 13    176
# 12    176
# 10    176
# 11    176
# 14    176
# 15    176
# 6      89
# 5      89
# 7      89
# 16     88
# 17     88
# 18     88
# 19     88
# 20     88
# 21     88
# 22     88
# Name: count, dtype: int64
# value counts for 'Amount of Credit Cards':
# Amount of Credit Cards
# 1    1922
# 2     765
# 3     313
# Name: count, dtype: int64
# value counts for 'Nationality':
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# value counts for 'Occupation':
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# ...

# %%
for i , predictor in enumerate(df[['BRId', 'GenderId', 'IAId', 'Amount of Credit Cards','Nationality', 'Occupation', 'Fee Structure','Loyalty Classification','Income_band','Properties Owned',
       'Risk Weighting']].columns):
  plt.figure(i)
  sns.countplot(x=predictor,data=df)

# %%
for i, predictor in enumerate(df[["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality", "Occupation", "Fee Structure", "Loyalty Classification", "Properties Owned", "Risk Weighting", "Income_band"]].columns):
    plt.figure(i)
    sns.countplot(data=df, x=predictor,hue='Nationality')

# %%
for column in categorical_columns:
  if column == "occupation":
    continue
  plt.figure(figsize=(8,4))
  sns.histplot(df[column])
  plt.title(f'Histogram of occupation')
  plt.xlabel(column)
  plt.ylabel('count')
  plt.show()

# %%
numrical_columns=['Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']
plt.figure(figsize=(12,6))
for i,column in enumerate(numrical_columns):
  plt.subplot(4,3,i+1)
  sns.histplot(df[column],kde=True)
  plt.title(column)
plt.show()

# %%
numerical_columns = ['Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']
correlation_matrix=df[numerical_columns].corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
missing_values=df.isnull().sum()
print(missing_values)
# Out:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# Income_band                 0
# dtype: int64

# %%
df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], format='%d-%m-%Y')
print(df['Joined Bank'].dtype)
# Out:
# datetime64[ns]

# %%
pairs_to_plot=[
    ('Bank Deposits', 'Saving Accounts'),
    ('Checking Accounts', 'Saving Accounts'),
    ('Checking Accounts', 'Foreign Currency Account'),
    ('Age', 'Superannuation Savings'),
    ('Estimated Income', 'Checking Accounts'),
    ('Bank Loans', 'Credit Card Balance'),
    ('Business Lending', 'Bank Loans'),
]
for x_col,y_col in pairs_to_plot:
  plt.figure(figsize=(10,6))
  sns.regplot(data=df,x=x_col,y=y_col,scatter_kws={'alpha': 0.4},line_kws={'color': 'red'} )
  plt.title(f'Relationship between {x_col} and {y_col}', fontsize=14)
  plt.xlabel(x_col, fontsize=12)
  plt.ylabel(y_col, fontsize=12)
  plt.tight_layout()
  plt.show()

# %% [markdown]
# Insights from the above data

# %% [markdown]
# ##Deposits and Savings Behavior
#
# The high correlation between Bank Deposits and Saving Accounts suggests that these may either measure overlapping financial behavior (e.g., total funds a customer keeps in the bank) or that people who actively deposit funds also tend to maintain or grow savings balances.
#
#
# ## Income, Age, and Accumulation
#
# Moderate correlations of Age and Estimated Income with various balances (Superannuation, Savings, Checking) reflect a common financial lifecycle trend: higher income earners and older individuals often accumulate more savings, retirement funds, and may carry higher credit card balances or loans.
#
#
# ##Low Correlation with Properties Owned
#
# Property ownership may depend on external factors (location, real estate market conditions, inheritance, etc.) that are not captured by these particular banking variables. Hence, we see weaker correlations here.
#
#
# ##Business vs. Personal Banking
#
#
# Business Lending’s moderate link to Bank Loans suggests some customers may have both personal and business debts. However, business lending is relatively uncorrelated with other deposit or property-related metrics, indicating it may serve a distinct subset of customers or needs.

# %% [markdown]
# Modelling

# %%
threshold = df['total_credit_exposure'].quantile(0.75)

df['high_credit_exposure_risk'] = (df['total_credit_exposure'] >= threshold).astype(int)
df['high_credit_exposure_risk']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 2995    0
# 2996    0
# 2997    0
# 2998    0
# 2999    0
# Name: high_credit_exposure_risk, Length: 3000, dtype: int64

# %%
df['total_credit_exposure'] = (df['Bank Loans'] + df['Credit Card Balance'] + df['Business Lending'])
df['total_credit_exposure']
# Out:
# 0       1911202.76
# 1       3273398.41
# 2       1605422.16
# 3       1273802.35
# 4       2726493.56
#            ...
# 2995    1463444.90
# 2996     874712.13
# 2997    1385793.09
# 2998    1810572.24
# 2999     616547.90
# Name: total_credit_exposure, Length: 3000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['high_credit_exposure_risk', 'total_credit_exposure'], axis=1)
y = df['high_credit_exposure_risk']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,stratify=y,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

logit= LogisticRegression(max_iter =2000, class_weight='balanced')
drop_columns = ['Client ID', 'Name', 'Location ID', 'Joined Bank', 'Banking Contact']

categorical_cols = ['Nationality', 'Occupation', 'Fee Structure', 'Loyalty Classification', 'Income_band']

X_train_processed = X_train.drop(columns=drop_columns)
X_test_processed = X_test.drop(columns=drop_columns)

numerical_cols = X_train_processed.select_dtypes(include=np.number).columns.tolist()
numerical_cols_to_exclude_from_scaling = ['BRId', 'GenderId', 'IAId', 'Amount of Credit Cards', 'Properties Owned', 'Risk Weighting', 'Age']
numerical_cols = [col for col in numerical_cols if col not in numerical_cols_to_exclude_from_scaling]

X_train_processed = pd.get_dummies(X_train_processed, columns=categorical_cols, drop_first=True)
X_test_processed = pd.get_dummies(X_test_processed, columns=categorical_cols, drop_first=True)

train_cols = X_train_processed.columns
test_cols = X_test_processed.columns

missing_in_test = set(train_cols) - set(test_cols)
for c in missing_in_test:
    X_test_processed[c] = 0

missing_in_train = set(test_cols) - set(train_cols)
for c in missing_in_train:
    X_train_processed[c] = 0

X_test_processed = X_test_processed[train_cols]

scaler = StandardScaler()
X_train_processed[numerical_cols] = scaler.fit_transform(X_train_processed[numerical_cols])
X_test_processed[numerical_cols] = scaler.transform(X_test_processed[numerical_cols])

logit.fit(X_train_processed,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=2000)

# %%
from sklearn.metrics import classification_report

y_pred = logit.predict(X_test_processed)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       563
#            1       0.95      1.00      0.98       187
#
#     accuracy                           0.99       750
#    macro avg       0.98      0.99      0.98       750
# weighted avg       0.99      0.99      0.99       750

# %%
from sklearn.metrics import roc_auc_score

y_prob = logit.predict_proba(X_test_processed)[:,1]
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC: 0.9999050160997711

# %%
coef_df = pd.DataFrame({'feature': X_train_processed.columns,'coefficient': logit.coef_[0]}).sort_values(by='coefficient', ascending=False)
coef_df
# Out:
#                              feature  coefficient
# 10                  Business Lending     7.641125
# 5                         Bank Loans     5.224062
# 159        Occupation_Research Nurse     0.750034
# 165  Occupation_Sales Representative     0.537429
# 41      Occupation_Assistant Manager     0.534877
# ..                               ...          ...
# 50     Occupation_Biostatistician II    -0.384489
# 188        Occupation_Statistician I    -0.414233
# 150      Occupation_Quality Engineer    -0.445622
# 78           Occupation_Developer II    -0.452383
# 69        Occupation_Data Coordiator    -0.556320
#
# [221 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=500,max_depth=6,min_samples_leaf=40,class_weight='balanced',random_state=42,n_jobs=-1)
rf.fit(X_train_processed,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=6,
#                        min_samples_leaf=40, n_estimators=500, n_jobs=-1,
#                        random_state=42)

# %%
from sklearn.metrics import roc_auc_score,classification_report

# %%
rf_prob=rf.predict_proba(X_test_processed)[:,1]
rf_pred=(rf_prob>0.35).astype(int)

# %%
print("RF ROC-AUC:", roc_auc_score(y_test, rf_prob))
print(classification_report(y_test, rf_pred))
# Out:
# RF ROC-AUC: 0.9814591426753165
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71       563
#            1       0.42      1.00      0.60       187
#
#     accuracy                           0.66       750
#    macro avg       0.71      0.77      0.65       750
# weighted avg       0.86      0.66      0.68       750

# %%
coef_df = (pd.DataFrame({ "Feature": X_train_processed.columns,"Coefficient": logit.coef_[0] }).sort_values(by="Coefficient", ascending=False))
coef_df.head(15)
# Out:
#                                      Feature  Coefficient
# 10                          Business Lending     7.641125
# 5                                 Bank Loans     5.224062
# 159                Occupation_Research Nurse     0.750034
# 165          Occupation_Sales Representative     0.537429
# 41              Occupation_Assistant Manager     0.534877
# 157         Occupation_Research Assistant IV     0.514915
# 82                         Occupation_Editor     0.486512
# 59          Occupation_Chief Design Engineer     0.460149
# 185          Occupation_Staff Accountant III     0.456288
# 140          Occupation_Programmer Analyst I     0.442311
# 131          Occupation_Office Assistant III     0.418301
# 44            Occupation_Associate Professor     0.412153
# 211              Occupation_Web Developer II     0.406825
# 36   Occupation_Administrative Assistant III     0.397568
# 46       Occupation_Automation Specialist II     0.392897

# %%
import shap

# %%
explainer =shap.TreeExplainer(rf)
shap_values=explainer.shap_values(X_test_processed)

# %%
shap.summary_plot(shap_values[:, :, 1],X_test_processed.values, feature_names=X_test_processed.columns.tolist(), plot_type="bar")

# %%
segment_df=X_test_processed.copy()

# %%
segment_df['y_true'] = y_test.values
segment_df['y_pred'] = rf_pred
segment_df['y_prob'] = rf_prob
segment_df['Income_band'] = X_test['Income_band'].values
segment_df['Age'] = X_test['Age'].values

# %%
segment_df.groupby('Income_band')[['y_true','y_pred']].mean()
# Out:
# /tmp/ipython-input-1228115388.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   segment_df.groupby('Income_band')[['y_true','y_pred']].mean()
#                y_true    y_pred
# Income_band
# low          0.100000  0.288889
# medium       0.282258  0.688172
# high         0.509259  0.990741

# %%
segment_df['Age_Group'] = pd.cut(segment_df['Age'],bins=[18,30,45,60,100])
segment_df.groupby('Age_Group')[['y_true','y_pred']].mean()
# Out:
# /tmp/ipython-input-3413780412.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   segment_df.groupby('Age_Group')[['y_true','y_pred']].mean()
#              y_true    y_pred
# Age_Group
# (18, 30]   0.263566  0.596899
# (30, 45]   0.327684  0.610169
# (45, 60]   0.254777  0.573248
# (60, 100]  0.198529  0.580882

# %%
X_stress=X_test_processed.copy()

# %%
income_cols=[c for c in X_stress.columns if 'Income' in c]
X_stress[income_cols]=X_stress[income_cols]*0.8

# %%
stress_prob = rf.predict_proba(X_stress)[:,1]
stress_pred = (stress_prob > 0.35).astype(int)

# %%
print("Base High-Risk Rate:", np.mean(rf_pred))
print("Stress High-Risk Rate:", np.mean(stress_pred))
# Out:
# Base High-Risk Rate: 0.588
# Stress High-Risk Rate: 0.5893333333333334
